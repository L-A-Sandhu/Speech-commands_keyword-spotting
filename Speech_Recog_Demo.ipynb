# %% [markdown]
# # Speech Command Recognition
#
# This notebook presents an attention model for speech command recognotion. We use Google Speech Commands Dataset to test the Keras generator for sound files and the proposed RNN attention model.
#
#
# ## Download files and load information
#
# Dynamically load speech data from the disk to allow handling big datasets.
#
# First step: download Google Speech Command Dataset and convert all WAV files to numpy arrays for faster load (about 10x faster than loading raw WAV).

# %%
useColab=False
if useColab:
    # %tensorflow_version 2.x
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/SpeechDownloader.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/SpeechGenerator.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/audioUtils.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/SpeechModels.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/requirements.txt
    # !pip install -r requirements.txt

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 2022-06-28 16:31:37.998838: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9774598135868248656
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4639113976695914246
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17502128283598500240
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10538938560
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7015688781950264517
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# 2022-06-28 16:31:38.810355: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-28 16:31:38.830885: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2899885000 Hz
# 2022-06-28 16:31:38.831445: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560bef585770 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-06-28 16:31:38.831457: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-06-28 16:31:38.832963: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-06-28 16:31:38.937615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 16:31:38.938726: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560bef62af50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-06-28 16:31:38.938740: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2022-06-28 16:31:38.938869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 16:31:38.938973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-06-28 16:31:38.938993: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-28 16:31:38.958443: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-06-28 16:31:38.970441: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-06-28 16:31:38.973244: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-06-28 16:31:38.994775: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-06-28 16:31:38.998630: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-06-28 16:31:39.044621: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-06-28 16:31:39.044925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 16:31:39.045498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 16:31:39.045744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-06-28 16:31:39.045826: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-28 16:31:39.354927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-28 16:31:39.354950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-06-28 16:31:39.354955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-06-28 16:31:39.355101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 16:31:39.355244: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 16:31:39.355348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/device:GPU:0 with 10050 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)

# %%
#%load_ext autoreload
#%autoreload 2

import librosa
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import SpeechDownloader
import SpeechGenerator
import SpeechModels

# %%
# Download and prepare all data
gscInfo, nCategs = SpeechDownloader.PrepareGoogleSpeechCmd(version=2, task='35word')
# Out:
# Downloading http://download.tensorflow.org/data/speech_commands_test_set_v0.02.tar.gz into sd_GSCmdV2/test.tar.gz
# 110kKB [01:31, 1.20kKB/s]
# Downloading http://download.tensorflow.org/data/speech_commands_v0.02.tar.gz into sd_GSCmdV2/train.tar.gz
# 2.37MKB [35:03, 1.13kKB/s]
# Extracting sd_GSCmdV2/test.tar.gz into sd_GSCmdV2/test/
# Extracting sd_GSCmdV2/train.tar.gz into sd_GSCmdV2/train/
# Converting test set WAVs to numpy files
# 100%|███████████████████████████████████████| 4890/4890 [08:17<00:00,  9.84it/s]
# Converting training set WAVs to numpy files
# 100%|█████████████████████████████████| 105835/105835 [2:59:28<00:00,  9.83it/s]
# Done preparing Google Speech commands dataset version 2

# %% [markdown]
# We should have 4 datasets, each with file names 'files' and their categories 'labels' in a dict.

# %%
print(gscInfo.keys())
print(gscInfo['train'].keys())
print(len(gscInfo['train']['files']))
print(nCategs)
# Out:
# dict_keys(['train', 'test', 'val', 'testREAL'])
# dict_keys(['files', 'labels'])
# 84849
# 36

# %% [markdown]
# # Speech Data Generator
#
# Use Keras to create a generator that reads files on the fly.

# %%
sr = 16000 #we know this one for google audios
iLen = 16000
trainGen = SpeechGenerator.SpeechGen(gscInfo['train']['files'], gscInfo['train']['labels'], shuffle=True)
# handle the fact that number of samples in validation may not be multiple of batch_size with shuffle=True
valGen   = SpeechGenerator.SpeechGen(gscInfo['val']['files'], gscInfo['val']['labels'], shuffle=True)

# use batch_size = total number of files to read all test files at once
testGen  = SpeechGenerator.SpeechGen(gscInfo['test']['files'], gscInfo['test']['labels'], shuffle=False, batch_size=len(gscInfo['test']['files']))
testRGen = SpeechGenerator.SpeechGen(gscInfo['testREAL']['files'], gscInfo['testREAL']['labels'], shuffle=False, batch_size=len(gscInfo['testREAL']['files']))
valGen.__len__()
# Out:
# 311

# %%
audios, classes = valGen.__getitem__(5)
classes
# Out:
# array([28, 10,  1, 15, 29,  2, 15,  8, 33, 11, 14, 17,  6, 28,  6, 12, 10,
#        16, 11,  6, 20,  8,  2, 30, 31, 20,  4, 25, 31, 13,  4, 14])

# %%
# librosa.output.write_wav('file.wav', audios[4], sr, norm=False)
plt.plot(audios[4])

# %%
from tensorflow.keras.models import Sequential
from kapre.time_frequency import Melspectrogram, Spectrogram
from kapre.utils import Normalization2D

melspecModel = Sequential()

melspecModel.add(Melspectrogram(n_dft=1024, n_hop=128, input_shape=(1, iLen),
                         padding='same', sr=sr, n_mels=80,
                         fmin=40.0, fmax=sr/2, power_melgram=1.0,
                         return_decibel_melgram=True, trainable_fb=False,
                         trainable_kernel=False,
                         name='mel_stft') )

melspecModel.add(Normalization2D(int_axis=0))

melspecModel.summary()
# Out:
# 2022-06-28 20:16:45.311681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.311950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-06-28 20:16:45.311976: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-28 20:16:45.311997: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-06-28 20:16:45.312009: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-06-28 20:16:45.312020: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-06-28 20:16:45.312031: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-06-28 20:16:45.312042: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-06-28 20:16:45.312053: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-06-28 20:16:45.312099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.312365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.312475: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-06-28 20:16:45.312782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.313013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-06-28 20:16:45.313025: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-28 20:16:45.313035: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-06-28 20:16:45.313045: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-06-28 20:16:45.313054: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-06-28 20:16:45.313064: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-06-28 20:16:45.313074: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-06-28 20:16:45.313083: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-06-28 20:16:45.313118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.313259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.313372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-06-28 20:16:45.313394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-28 20:16:45.313398: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-06-28 20:16:45.313403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-06-28 20:16:45.313463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.313778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 20:16:45.313888: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10050 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mel_stft (Melspectrogram)    (None, 80, 125, 1)        1091664
# _________________________________________________________________
# normalization2d (Normalizati (None, 80, 125, 1)        0
# =================================================================
# Total params: 1,091,664
# Trainable params: 1,091,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
melspec = melspecModel.predict( audios.reshape((-1,1,iLen)) )
melspec.shape
# Out:
# 2022-06-28 20:16:45.913241: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-06-28 20:16:46.161070: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# (32, 80, 125, 1)

# %%
plt.figure(figsize=(17,6))
plt.pcolormesh(melspec[9,:,:,0])

plt.title('Spectrogram visualization')
plt.ylabel('Frequency')
plt.xlabel('Time')

plt.show()

# %%
# Check if mel spectrogram matches the one computed with librosa
librosa_melspec = librosa.feature.melspectrogram(y=audios[9], sr=sr, n_fft=1024,
                                                 hop_length=128, power=1.0, #window='hann',
                                                 n_mels=80, fmin=40.0, fmax=sr/2)
S_dB = librosa.power_to_db(librosa_melspec, ref=np.max)

# %%
plt.figure(figsize=(17,6))
plt.pcolormesh(S_dB)

plt.title('Spectrogram visualization - librosa')
plt.ylabel('Frequency')
plt.xlabel('Time')

plt.show()

# %%
# plt.hist(melspec.flatten(), bins=100)

# %% [markdown]
# # Models
#
# Create Keras models to see if the generators are working properly

# %%
from tensorflow.keras.models import Model, load_model

from kapre.time_frequency import Melspectrogram, Spectrogram

# %%
#self-attention LSTM
#nCategs=36
#sr=16000
#iLen=16000
#from keras import layers as L

model = SpeechModels.AttRNNSpeechModel(nCategs, samplingrate = sr, inputLength = None)#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['sparse_categorical_accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None)]       0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, None)      0           input[0][0]
# __________________________________________________________________________________________________
# mel_stft (Melspectrogram)       (None, 80, None, 1)  1091664     reshape[0][0]
# __________________________________________________________________________________________________
# mel_stft_norm (Normalization2D) (None, 80, None, 1)  0           mel_stft[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, None, 80, 1)  0           mel_stft_norm[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, 80, 10) 60          permute[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, 80, 10) 40          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, 80, 1)  51          batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, 80, 1)  4           conv2d_1[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, None, 80)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, None, 128)    74240       squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, None, 128)    98816       bidirectional[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16512       lambda[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, None)         0           dense[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# attSoftmax (Softmax)            (None, None)         0           dot[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 128)          0           attSoftmax[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dot_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 36)           1188        dense_2[0][0]
# ==================================================================================================
# Total params: 1,292,911
# Trainable params: 201,225
# Non-trainable params: 1,091,686
# __________________________________________________________________________________________________

# %%
# model.load_weights('model-attRNN.h5')

# %%
import math
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.4
    epochs_drop = 15.0
    lrate = initial_lrate * math.pow(drop,  
            math.floor((1+epoch)/epochs_drop))
    
    if (lrate < 4e-5):
        lrate = 4e-5
      
    print('Changing learning rate to {}'.format(lrate))
    return lrate
lrate = LearningRateScheduler(step_decay)

# %%
earlystopper = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=10,
                             verbose=1, restore_best_weights=True)
checkpointer = ModelCheckpoint('model-attRNN.h5', monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True)

results = model.fit(trainGen, validation_data=valGen, epochs=60, use_multiprocessing=False, workers=4, verbose=2,
                    callbacks=[earlystopper, checkpointer, lrate])

model.save('model-attRNN.h5')
# Out:
# Changing learning rate to 0.001
# Epoch 1/60
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.89942, saving model to model-attRNN.h5
# 2651/2651 - 86s - loss: 0.7844 - sparse_categorical_accuracy: 0.7799 - val_loss: 0.3612 - val_sparse_categorical_accuracy: 0.8994
# Changing learning rate to 0.001
# Epoch 2/60
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.89942 to 0.91710, saving model to model-attRNN.h5
# 2651/2651 - 74s - loss: 0.3441 - sparse_categorical_accuracy: 0.9029 - val_loss: 0.2882 - val_sparse_categorical_accuracy: 0.9171
# Changing learning rate to 0.001
# Epoch 3/60
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.91710 to 0.92193, saving model to model-attRNN.h5
# 2651/2651 - 67s - loss: 0.2648 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.2787 - val_sparse_categorical_accuracy: 0.9219
# Changing learning rate to 0.001
# Epoch 4/60
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.92193 to 0.93137, saving model to model-attRNN.h5
# 2651/2651 - 71s - loss: 0.2214 - sparse_categorical_accuracy: 0.9366 - val_loss: 0.2550 - val_sparse_categorical_accuracy: 0.9314
# Changing learning rate to 0.001
# Epoch 5/60
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.93137 to 0.93489, saving model to model-attRNN.h5
# 2651/2651 - 69s - loss: 0.1969 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.2313 - val_sparse_categorical_accuracy: 0.9349
# Changing learning rate to 0.001
# Epoch 6/60
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.93489 to 0.93609, saving model to model-attRNN.h5
# 2651/2651 - 73s - loss: 0.1739 - sparse_categorical_accuracy: 0.9507 - val_loss: 0.2399 - val_sparse_categorical_accuracy: 0.9361
# Changing learning rate to 0.001
# Epoch 7/60
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.93609 to 0.93840, saving model to model-attRNN.h5
# 2651/2651 - 74s - loss: 0.1585 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.2226 - val_sparse_categorical_accuracy: 0.9384
# Changing learning rate to 0.001
# Epoch 8/60
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.93840
# 2651/2651 - 72s - loss: 0.1439 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.2345 - val_sparse_categorical_accuracy: 0.9364
# Changing learning rate to 0.001
# Epoch 9/60
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.93840
# 2651/2651 - 74s - loss: 0.1338 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.2440 - val_sparse_categorical_accuracy: 0.9365
# Changing learning rate to 0.001
# Epoch 10/60
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.93840
# 2651/2651 - 74s - loss: 0.1232 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.2351 - val_sparse_categorical_accuracy: 0.9378
# Changing learning rate to 0.001
# Epoch 11/60
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.93840 to 0.93951, saving model to model-attRNN.h5
# 2651/2651 - 75s - loss: 0.1176 - sparse_categorical_accuracy: 0.9673 - val_loss: 0.2419 - val_sparse_categorical_accuracy: 0.9395
# Changing learning rate to 0.001
# Epoch 12/60
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.93951 to 0.93981, saving model to model-attRNN.h5
# 2651/2651 - 78s - loss: 0.1131 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.2444 - val_sparse_categorical_accuracy: 0.9398
# Changing learning rate to 0.001
# Epoch 13/60
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.93981
# 2651/2651 - 74s - loss: 0.1028 - sparse_categorical_accuracy: 0.9717 - val_loss: 0.2419 - val_sparse_categorical_accuracy: 0.9396
# Changing learning rate to 0.001
# Epoch 14/60
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.93981
# 2651/2651 - 77s - loss: 0.0995 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.2396 - val_sparse_categorical_accuracy: 0.9385
# Changing learning rate to 0.0004
# Epoch 15/60
#
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.93981 to 0.94584, saving model to model-attRNN.h5
# 2651/2651 - 73s - loss: 0.0696 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.2264 - val_sparse_categorical_accuracy: 0.9458
# Changing learning rate to 0.0004
# Epoch 16/60
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 75s - loss: 0.0618 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.2404 - val_sparse_categorical_accuracy: 0.9429
# Changing learning rate to 0.0004
# Epoch 17/60
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 74s - loss: 0.0582 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.2408 - val_sparse_categorical_accuracy: 0.9443
# Changing learning rate to 0.0004
# Epoch 18/60
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 73s - loss: 0.0560 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.2413 - val_sparse_categorical_accuracy: 0.9440
# Changing learning rate to 0.0004
# Epoch 19/60
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 74s - loss: 0.0533 - sparse_categorical_accuracy: 0.9874 - val_loss: 0.2506 - val_sparse_categorical_accuracy: 0.9449
# Changing learning rate to 0.0004
# Epoch 20/60
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 73s - loss: 0.0548 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.2557 - val_sparse_categorical_accuracy: 0.9426
# Changing learning rate to 0.0004
# Epoch 21/60
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 72s - loss: 0.0479 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.2515 - val_sparse_categorical_accuracy: 0.9452
# Changing learning rate to 0.0004
# Epoch 22/60
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 74s - loss: 0.0488 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.2551 - val_sparse_categorical_accuracy: 0.9440
# Changing learning rate to 0.0004
# Epoch 23/60
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 73s - loss: 0.0465 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.2651 - val_sparse_categorical_accuracy: 0.9432
# Changing learning rate to 0.0004
# Epoch 24/60
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 74s - loss: 0.0438 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.2711 - val_sparse_categorical_accuracy: 0.9427
# Changing learning rate to 0.0004
# Epoch 25/60
# Restoring model weights from the end of the best epoch.
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.94584
# 2651/2651 - 71s - loss: 0.0393 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.2772 - val_sparse_categorical_accuracy: 0.9431
# Epoch 00025: early stopping

# %%
# summarize history for categorical accuracy
plt.plot(results.history['sparse_categorical_accuracy'])
plt.plot(results.history['val_sparse_categorical_accuracy'])
plt.title('Categorical accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# results.history

# %%
# load best model according to cross-validation - model-attRNN
# model = load_model('model-attRNN.h5', custom_objects={'Melspectrogram': Melspectrogram, 'Normalization2D': Normalization2D })
model.load_weights('model-attRNN.h5')

# %%
#read all test data
x_test, y_test = testGen.__getitem__(0)

# %%
valEval = model.evaluate(valGen, use_multiprocessing=False, workers=4,verbose=0)
trainEval = model.evaluate(trainGen, use_multiprocessing=False, workers=4,verbose=0)
testEval = model.evaluate(x_test, y_test, verbose=0)
print('Evaluation scores: \nMetrics: {} \nTrain: {} \nValidation: {} \nTest: {}'.format(model.metrics_names, trainEval, valEval, testEval) )
# Out:
# 2022-06-28 20:48:22.355896: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 704320000 exceeds 10% of free system memory.
# Evaluation scores:
# Metrics: ['loss', 'sparse_categorical_accuracy']
# Train: [0.05894545093178749, 0.9862434267997742]
# Validation: [0.21920396387577057, 0.9471462965011597]
# Test: [0.2249133437871933, 0.9386642575263977]

# %%
kaggle12cmd = False
if kaggle12cmd:
    #only for the Kaggle competition, 12-cmd
    x_testR, y_testR = testRGen.__getitem__(0)
    testREval = model.evaluate(x_testR, y_testR, verbose=1)
    print(testREval)
    testREval = model.evaluate(testRGen, use_multiprocessing=True, workers=4,verbose=1)
    print(testREval)

# %% [markdown]
# ## Evaluation and Attention Plots

# %%
attSpeechModel = Model(inputs=model.input,
                                 outputs=[model.get_layer('output').output, 
                                          model.get_layer('attSoftmax').output,
                                          model.get_layer('mel_stft').output])

# %%
audios, classes = valGen.__getitem__(3)
classes
# Out:
# array([22, 25,  1, 29, 10, 32, 33, 23, 23,  9, 20, 14, 31, 35, 13, 12, 15,
#        28,  1, 16,  3, 25, 17, 14, 11, 15,  5, 12, 31,  9, 13, 32])

# %%
#8 - on, 13 - one, 7 - right
idAudio = 8
classes[idAudio]
# Out:
# 23

# %%
outs, attW, specs = attSpeechModel.predict(audios)

# %%
np.argmax(outs,axis=1)
# Out:
# array([22, 25,  1, 29, 10, 32, 33, 23, 23,  9, 20, 14, 31, 35, 13, 12, 15,
#        28,  1, 16,  3, 25, 17, 14, 11, 18,  5, 12, 31,  9, 13, 15])

# %%
specs.shape
# Out:
# (32, 80, 125, 1)

# %%
imgHeight = 2

plt.figure(figsize=(17,imgHeight))
plt.title('Raw waveform', fontsize=30)
plt.ylabel('Amplitude', fontsize=30)
plt.xlabel('Sample index', fontsize=30)
plt.plot(audios[idAudio])
plt.savefig('picrawWave.png', dpi = 400)
plt.show()

plt.figure(figsize=(17,imgHeight))
plt.title('Attention weights (log)', fontsize=30)
plt.ylabel('Log of attention weight', fontsize=30)
plt.xlabel('Mel-spectrogram index', fontsize=30)
plt.plot(np.log(attW[idAudio]))
plt.savefig('picAttention.png', dpi = 400)
plt.show()


plt.figure(figsize=(17,imgHeight*2))
plt.pcolormesh(specs[idAudio,:,:,0])

plt.title('Spectrogram visualization', fontsize=30)
plt.ylabel('Frequency', fontsize=30)
plt.xlabel('Time', fontsize=30)
plt.savefig('picmelSpec.png', dpi = 400)

plt.show()

# %%
y_pred = model.predict(x_test, verbose=1)
# Out:
# 2022-06-28 20:48:31.078477: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 704320000 exceeds 10% of free system memory.
#   1/344 [..............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0054s vs `on_predict_batch_end` time: 0.0103s). Check your callbacks.
# 344/344 [==============================] - 4s 12ms/step

# %%
from sklearn.metrics import confusion_matrix
import audioUtils
cm = confusion_matrix(y_test, np.argmax(y_pred,1))

# %%
#set(y_test)

# %%
#35word, v2
classes = ['nine', 'yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go',
           'zero', 'one', 'two', 'three', 'four', 'five', 'six', 
           'seven',  'eight', 'backward', 'bed', 'bird', 'cat', 'dog',
           'follow', 'forward', 'happy', 'house', 'learn', 'marvin', 'sheila', 'tree',
           'visual', 'wow']

# %%
#35word, v1
#classes=['nine', 'yes',  'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go',
#         'zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven',  'eight', 
#         'bed', 'bird', 'cat', 'dog', 'happy', 'house', 
#         'marvin', 'sheila', 'tree', 'wow']

# %%
#20cmd
#classes=['unknown', 'nine', 'yes',  'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go',
#         'zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven',  'eight']

# %%
audioUtils.plot_confusion_matrix(cm, classes, normalize=False)
# Out:
# Confusion matrix, without normalization

# %%
import pandas as pd
import kapre
[tf.__version__, kapre.__version__, pd.__version__, librosa.__version__]
# Out:
# ['2.3.0', '0.2.0', '1.0.5', '0.8.0']

# %% [markdown]
# # Save model to .pb

# %%
#model = SpeechModels.AttRNNSpeechModel(nCategs, samplingrate = sr, inputLength = None)#, rnn_func=L.LSTM)
#model.load_weights('model-attRNN.h5')

model = load_model('model-attRNN.h5', custom_objects={'Melspectrogram': Melspectrogram, 'Normalization2D': Normalization2D })

# %%
tf.saved_model.save(model, "attRNNModel/1/")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: attRNNModel/1/assets

# %%
import os
os.listdir('attRNNModel/1/')
# Out:
# ['assets', 'saved_model.pb', 'variables']

# %%
# if using tensorflow 1.x

# %%
# save model to pb ====================
def freeze_session(session, keep_var_names=None, output_names=None, clear_devices=True):
    """
    Freezes the state of a session into a pruned computation graph.
    Creates a new computation graph where variable nodes are replaced by
    constants taking their current value in the session. The new graph will be
    pruned so subgraphs that are not necessary to compute the requested
    outputs are removed.
    @param session The TensorFlow session to be frozen.
    @param keep_var_names A list of variable names that should not be frozen,
                          or None to freeze all the variables in the graph.
    @param output_names Names of the relevant graph outputs.
    @param clear_devices Remove the device directives from the graph for better portability.
    @return The frozen graph definition.
    """
    from tensorflow.python.framework.graph_util import convert_variables_to_constants
    graph = session.graph
    with graph.as_default():
        freeze_var_names = list(set(v.op.name for v in tf.global_variables()).difference(keep_var_names or []))
        output_names = output_names or []
        output_names += [v.op.name for v in tf.global_variables()]
        input_graph_def = graph.as_graph_def()
        if clear_devices:
            for node in input_graph_def.node:
                node.device = ""
        frozen_graph = convert_variables_to_constants(session, input_graph_def,
                                                      output_names, freeze_var_names)
        return frozen_graph

# %%
wkdir = ''
pb_filename = 'attRNN.pb'

# save keras model as tf pb files ===============
sess = tf.compat.v1.keras.backend.get_session()

#frozen_graph = freeze_session(sess,
#                              output_names=[out.op.name for out in model.outputs])
#tf.train.write_graph(frozen_graph, wkdir, pb_filename, as_text=False)
